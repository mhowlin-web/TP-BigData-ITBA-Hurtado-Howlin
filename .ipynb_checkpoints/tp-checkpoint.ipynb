# %%
# TP Big Data — ITBA

**Autores:** Hurtado, Howlin

---

## Descripción

Este notebook corresponde al Trabajo Práctico de la materia **Big Data** del ITBA.

## Estructura

- Exploración y análisis de datos
- Procesamiento con herramientas de Big Data
- Conclusiones y resultados

# %%
# %pip install --upgrade pydantic
# %pip uninstall -y evidently
# %pip install evidently
# %pip install --upgrade evidently
# Out:
# Requirement already satisfied: pydantic in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic) (0.4.2)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: evidently 0.7.21
# Uninstalling evidently-0.7.21:
#   Successfully uninstalled evidently-0.7.21
# Note: you may need to restart the kernel to use updated packages.
# Collecting evidently
#   Using cached evidently-0.7.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2026.2.25)
# Requirement already satisfied: cryptography>=43.0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (46.0.5)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.1.0)
# Requirement already satisfied: dynaconf>=3.2.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (3.2.13)
# Requirement already satisfied: fsspec>=2024.9.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2026.3.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.0.10)
# Requirement already satisfied: litestar>=2.19.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.21.1)
# Requirement already satisfied: nltk>=3.6.7 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (3.9.4)
# Requirement already satisfied: numpy>=1.23.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.4.3)
# Requirement already satisfied: opentelemetry-proto>=1.25.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.40.0)
# Requirement already satisfied: pandas>=1.3.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas[parquet]>=1.3.5->evidently) (3.0.1)
# Requirement already satisfied: plotly<6,>=5.10.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (5.24.1)
# Requirement already satisfied: pydantic>=1.10.16 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (6.0.2)
# Requirement already satisfied: requests>=2.32.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.32.4)
# Requirement already satisfied: rich>=13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (13.9.4)
# Requirement already satisfied: scikit-learn>=1.1.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.8.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.17.1)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.14.6)
# Requirement already satisfied: typer>=0.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.24.1)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.9.0)
# Requirement already satisfied: ujson>=5.4.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (5.12.0)
# Requirement already satisfied: urllib3>=1.26.19 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.6.3)
# Requirement already satisfied: uuid6>=2024.7.10 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2025.0.1)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.40.0)
# Requirement already satisfied: watchdog>=3.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (6.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from cryptography>=43.0.1->evidently) (2.0.0)
# Requirement already satisfied: packaging in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from deprecation>=2.1.0->evidently) (24.2)
# Requirement already satisfied: appdirs in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: filelock in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (3.20.3)
# Requirement already satisfied: distro in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (1.9.0)
# Requirement already satisfied: anyio>=3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (4.12.1)
# Requirement already satisfied: click in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (8.2.1)
# Requirement already satisfied: httpx>=0.22 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.20.0)
# Requirement already satisfied: multidict>=6.0.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.3.1)
# Requirement already satisfied: polyfactory>=2.6.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (3.3.0)
# Requirement already satisfied: rich-click in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.9.7)
# Requirement already satisfied: sniffio>=1.3.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.3.1)
# Requirement already satisfied: typing-extensions in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (4.14.1)
# Requirement already satisfied: joblib in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (2026.2.28)
# Requirement already satisfied: tqdm in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (4.66.4)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from opentelemetry-proto>=1.25.0->evidently) (6.33.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2.9.0.post0)
# Requirement already satisfied: pyarrow>=13.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas[parquet]>=1.3.5->evidently) (23.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from plotly<6,>=5.10.0->evidently) (9.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from requests>=2.32.0->evidently) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from requests>=2.32.0->evidently) (3.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from rich>=13->evidently) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from rich>=13->evidently) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from scikit-learn>=1.1.1->evidently) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from statsmodels>=0.14.0->evidently) (1.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typer>=0.3->evidently) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typer>=0.3->evidently) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typing-inspect>=0.9.0->evidently) (1.1.0)
# Requirement already satisfied: h11>=0.8 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (16.0)
# Requirement already satisfied: pycparser in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently) (2.23)
# Requirement already satisfied: httpcore==1.* in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from httpx>=0.22->litestar>=2.19.0->evidently) (1.0.9)
# Requirement already satisfied: mdurl~=0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently) (0.1.2)
# Requirement already satisfied: faker>=5.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from polyfactory>=2.6.3->litestar>=2.19.0->evidently) (40.11.1)
# Requirement already satisfied: six>=1.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (1.17.0)
# Using cached evidently-0.7.21-py3-none-any.whl (11.7 MB)
# Installing collected packages: evidently
# Successfully installed evidently-0.7.21
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: evidently in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (0.7.21)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2026.2.25)
# Requirement already satisfied: cryptography>=43.0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (46.0.5)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.1.0)
# Requirement already satisfied: dynaconf>=3.2.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (3.2.13)
# Requirement already satisfied: fsspec>=2024.9.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2026.3.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.0.10)
# Requirement already satisfied: litestar>=2.19.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.21.1)
# Requirement already satisfied: nltk>=3.6.7 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (3.9.4)
# Requirement already satisfied: numpy>=1.23.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.4.3)
# Requirement already satisfied: opentelemetry-proto>=1.25.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.40.0)
# Requirement already satisfied: pandas>=1.3.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas[parquet]>=1.3.5->evidently) (3.0.1)
# Requirement already satisfied: plotly<6,>=5.10.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (5.24.1)
# Requirement already satisfied: pydantic>=1.10.16 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (6.0.2)
# Requirement already satisfied: requests>=2.32.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.32.4)
# Requirement already satisfied: rich>=13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (13.9.4)
# Requirement already satisfied: scikit-learn>=1.1.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.8.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (1.17.1)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.14.6)
# Requirement already satisfied: typer>=0.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.24.1)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (0.9.0)
# Requirement already satisfied: ujson>=5.4.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (5.12.0)
# Requirement already satisfied: urllib3>=1.26.19 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2.6.3)
# Requirement already satisfied: uuid6>=2024.7.10 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (2025.0.1)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.40.0)
# Requirement already satisfied: watchdog>=3.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from evidently) (6.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from cryptography>=43.0.1->evidently) (2.0.0)
# Requirement already satisfied: packaging in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from deprecation>=2.1.0->evidently) (24.2)
# Requirement already satisfied: appdirs in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: filelock in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (3.20.3)
# Requirement already satisfied: distro in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from iterative-telemetry>=0.0.5->evidently) (1.9.0)
# Requirement already satisfied: anyio>=3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (4.12.1)
# Requirement already satisfied: click in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (8.2.1)
# Requirement already satisfied: httpx>=0.22 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (0.20.0)
# Requirement already satisfied: multidict>=6.0.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.3.1)
# Requirement already satisfied: polyfactory>=2.6.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (3.3.0)
# Requirement already satisfied: rich-click in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.9.7)
# Requirement already satisfied: sniffio>=1.3.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (1.3.1)
# Requirement already satisfied: typing-extensions in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from litestar>=2.19.0->evidently) (4.14.1)
# Requirement already satisfied: joblib in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (2026.2.28)
# Requirement already satisfied: tqdm in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (4.66.4)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from opentelemetry-proto>=1.25.0->evidently) (6.33.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2.9.0.post0)
# Requirement already satisfied: pyarrow>=13.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pandas[parquet]>=1.3.5->evidently) (23.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from plotly<6,>=5.10.0->evidently) (9.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from pydantic>=1.10.16->evidently) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from requests>=2.32.0->evidently) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from requests>=2.32.0->evidently) (3.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from rich>=13->evidently) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from rich>=13->evidently) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from scikit-learn>=1.1.1->evidently) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from statsmodels>=0.14.0->evidently) (1.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typer>=0.3->evidently) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typer>=0.3->evidently) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from typing-inspect>=0.9.0->evidently) (1.1.0)
# Requirement already satisfied: h11>=0.8 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.22.0->evidently) (16.0)
# Requirement already satisfied: pycparser in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently) (2.23)
# Requirement already satisfied: httpcore==1.* in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from httpx>=0.22->litestar>=2.19.0->evidently) (1.0.9)
# Requirement already satisfied: mdurl~=0.1 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently) (0.1.2)
# Requirement already satisfied: faker>=5.0.0 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from polyfactory>=2.6.3->litestar>=2.19.0->evidently) (40.11.1)
# Requirement already satisfied: six>=1.5 in /Users/dyhurtado/.fury/fury_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %restart_python
# Out:
# UsageError: Line magic function `%restart_python` not found.

# %% [markdown]
# Buenas Como andan?
